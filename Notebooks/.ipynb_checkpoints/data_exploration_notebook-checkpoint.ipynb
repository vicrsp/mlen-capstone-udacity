# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pyarrow.parquet as pq
import gc
import pywt
from statsmodels.robust import mad
import scipy
from scipy import signal
from scipy.signal import butter
import sys
import time 

plt.style.use('ggplot')
data_dir = '../Input'
report_dir = '../Report'

sys.path.append('../')

from Source.feature_extraction import *
from Source.signal_denoising import *

# %% [markdown]
# ### Data Description

# %%
metadata_train = pd.read_csv(data_dir + '/metadata_train.csv', sep = ",")
metadata_train.head()
print('Number of signals: {}'.format(metadata_train.shape[0]) )
# Out:
# Number of signals: 8712

# %%
fig = plt.figure(figsize = (12,6))
sns.countplot(data=metadata_train, x = 'target', hue='phase')
plt.title('Target values distribution per phase')

plt.savefig(report_dir + '/train_data_dist.png')

# %%
fig = plt.figure(figsize = (12,6))
sns.countplot(data=metadata_train, x = 'target')
plt.title('Target values distribution')

plt.savefig(report_dir + '/train_data_dist_targets.png')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

sns.countplot(data=metadata_train, x = 'target', hue='phase', ax = ax[0])
ax[0].set_title('Target values distribution per phase')

sns.countplot(data=metadata_train, x = 'target', ax = ax[1])
ax[1].set_title('Target values distribution')

plt.savefig(report_dir + '/train_data_dist_twosided.png')

# %%
metadata_train.target.value_counts() / metadata_train.shape[0]
# Out:
# 0    0.939738
# 1    0.060262
# Name: target, dtype: float64

# %%
SAMPLING_FREQ = 800000 / 0.02  # 800,000 data points taken over 20 ms

# %%
subset_train = pq.read_pandas(data_dir + '/train.parquet', columns=[str(i) for i in range(0,3)]).to_pandas()


plt.figure(figsize=(12, 6))
time = subset_train.index * 1000 / SAMPLING_FREQ #s
plt.plot(time,subset_train['0'], label='Phase 0')
plt.plot(time,subset_train['1'], label='Phase 1')
plt.plot(time,subset_train['2'], label='Phase 2')
plt.ylabel('Amplitude (bit)')
plt.xlabel('Time (ms)')
plt.title('PD signals')
plt.legend()
plt.savefig(report_dir + '/signal_phase_example.png')

# %% [markdown]
# ### Signal Filtering

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(18, 8))
time = subset_train.index * 1000 / SAMPLING_FREQ #s

# FIG 1
ax[0].plot(time, subset_train['0'],'b', alpha=0.5)
ax[0].legend(['Original'], fontsize=14)
ax[0].set_ylabel('Amplitude (bit)')
ax[0].set_xlabel('Time (ms)')

ax[1].plot(time, high_pass_filter(subset_train['0'], low_cutoff = 10000), 'r', alpha=0.5)
ax[1].legend(['High pass filter'], fontsize=14)
ax[1].set_ylabel('Amplitude (bit)')
ax[1].set_xlabel('Time (ms)')

ax[2].plot(time, denoise_signal(subset_train['0'], low_freq = 10000), 'g', alpha=0.5)
ax[2].legend(['High pass filter and DWT denoising'], fontsize=14)
ax[2].set_ylabel('Amplitude (bit)')
ax[2].set_xlabel('Time (ms)')

"""
# FIG 1
ax[0,0].plot(subset_train['0'], alpha=0.5)
ax[0,0].legend(['Original'], fontsize=24)

ax[0,1].plot(x_hp, 'r', alpha=0.5)
ax[0,1].legend(['High pass filter'], fontsize=24)

ax[0,2].plot(x_dn, 'g', alpha=0.5)
ax[0,2].legend(['High pass filter and DWT denoising'], fontsize=24)


# FIG 2
ax[1,0].plot(subset_train['1'], alpha=0.5)
ax[1,0].legend(['Original'], fontsize=24)

ax[1,1].plot(x_hp, 'r', alpha=0.5)
ax[1,1].legend(['High pass filter'], fontsize=24)

ax[1,2].plot(x_dn, 'g', alpha=0.5)
ax[1,2].legend(['HP filter and denoising'], fontsize=24)


# FIG 3
ax[2,0].plot(subset_train['2'], alpha=0.5)
ax[2,0].legend(['Original'], fontsize=24)

ax[2,1].plot(x_hp, 'r', alpha=0.5)
ax[2,1].legend(['HP filter'], fontsize=24)

ax[2,2].plot(x_dn, 'g', alpha=0.5)
ax[2,2].legend(['HP filter and denoising'], fontsize=24)

"""
plt.savefig(report_dir + '/signal_phase_denoised.png')

# %% [markdown]
# ### Feature Extraction

# %%
x_dn = denoise_signal(subset_train['0'], low_freq = 10000)   
peaks, properties = signal.find_peaks(x_dn, prominence = 10, distance = 50)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))
time = subset_train.index * 1000 / SAMPLING_FREQ #s

ax.plot(time, x_dn)
ax.plot(time[peaks], x_dn[peaks], "x", label='Peak')
ax.set_ylabel('Amplitude (bit)')
ax.set_xlabel('Time (ms)')
ax.set_title('Signal peaks')
plt.legend()
plt.savefig(report_dir + '/signal_peaks.png')

# %%
time = subset_train.index * 1000 / SAMPLING_FREQ #s
r = range(519050,519100)

x_dn_ss = x_dn[r]
time_ss = time[r]
peaks, properties = signal.find_peaks(x_dn_ss, prominence = 10, distance = 50)
widths = signal.peak_widths(x_dn_ss, peaks, rel_height=0.9)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))
ax.plot(x_dn_ss)
ax.plot(peaks, x_dn_ss[peaks], "x", label='Peak')
ax.set_ylabel('Amplitude (bit)')
ax.set_xlabel('Index')
ax.vlines(x=peaks, ymin=x_dn_ss[peaks] - properties["prominences"], ymax = x_dn_ss[peaks], color = "C5", label='Height')
ax.hlines(*widths[1:], color = "C4", label='Width')
plt.legend()
ax.set_title('Peak height and width')
plt.savefig(report_dir + '/signal_peak_zoom.png')

# %%
id_signal_normal = metadata_train[metadata_train.target == 0]['signal_id'].iloc[3]
id_signal_fault = metadata_train[metadata_train.target == 1]['signal_id'].iloc[3]

signal_raw_normal = pq.read_pandas(data_dir + '/train.parquet', columns = [str(id_signal_normal)]).to_pandas().squeeze()
signal_raw_fault = pq.read_pandas(data_dir + '/train.parquet', columns = [str(id_signal_fault)]).to_pandas().squeeze()

# %%
fig, ax = plt.subplots(2, 1, figsize = (12,8))
time = signal_raw_fault.index * 1000 / SAMPLING_FREQ #s

ax[0].plot(time, signal_raw_fault)
ax[0].set_title('Fault signal')
ax[0].set_ylabel('Amplitude (bit)')

ax[1].plot(time, signal_raw_normal)
ax[1].set_title('Normal signal')
ax[1].set_xlabel('Time (ms)')
ax[1].set_ylabel('Amplitude (bit)')

plt.savefig(report_dir + '/signal_fault_normal_raw.png')

# %%
f, Pxx_den = signal.welch(signal_raw_fault, SAMPLING_FREQ)
f2, Pxx_den2 = signal.welch(signal_raw_normal, SAMPLING_FREQ)

fig, ax = plt.subplots(2, 1, figsize = (12,8))

ax[0].semilogy(f/1000000, Pxx_den)
ax[0].set_xlabel('')
ax[0].set_ylabel('PSD')
ax[0].set_title('Fault signal periodogram')

ax[1].semilogy(f2/1000000, Pxx_den2)
ax[1].set_title('Normal signal periodogram')
ax[1].set_xlabel('Frequency [MHz]')
ax[1].set_ylabel('PSD')


plt.savefig(report_dir + '/signal_fault_normal_psd_raw.png')

# %%
signal_fault_dn = denoise_signal(signal_raw_fault, wavelet='db4', level=2, low_freq=10000, mode='zero')
signal_normal_dn = denoise_signal(signal_raw_normal, wavelet='db4', level=2, low_freq=10000, mode='zero')

# %%
f, Pxx_den = signal.welch(signal_fault_dn, SAMPLING_FREQ)
f2, Pxx_den2 = signal.welch(signal_normal_dn, SAMPLING_FREQ)

fig, ax = plt.subplots(2, 1, figsize = (12,8))

ax[0].semilogy(f/1000000, Pxx_den)
ax[0].set_xlabel('')
ax[0].set_ylabel('PSD')
ax[0].set_title('Fault signal periodogram')

ax[1].semilogy(f2/1000000, Pxx_den2)
ax[1].set_title('Normal signal periodogram')
ax[1].set_xlabel('Frequency [MHz]')
ax[1].set_ylabel('PSD')


plt.savefig(report_dir + '/signal_fault_normal_psd_denoised.png')

# %% [markdown]
# ### Data Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
output_dir ='../Output'
features_raw = pd.read_csv(output_dir + '/all_features.csv', sep=";")

features_raw.columns
# Out:
# Index(['Unnamed: 0', 'signal_id', 'id_measurement', 'phase', 'target',
#        'number_of_peaks_p1', 'number_of_peaks_p2', 'number_of_peaks_p3',
#        'number_of_peaks_p4', 'mean_width_of_peaks_p1',
#        'mean_width_of_peaks_p2', 'mean_width_of_peaks_p4',
#        'mean_width_of_peaks_p3', 'max_width_of_peaks_p1',
#        'max_width_of_peaks_p2', 'max_width_of_peaks_p3',
#        'max_width_of_peaks_p4', 'min_width_of_peaks_p1',
#        'min_width_of_peaks_p2', 'min_width_of_peaks_p4',
#        'min_width_of_peaks_p3', 'mean_height_of_peaks_p1',
#        'mean_height_of_peaks_p2', 'mean_height_of_peaks_p4',
#        'mean_height_of_peaks_p3', 'max_height_of_peaks_p1',
#        'max_height_of_peaks_p2', 'max_height_of_peaks_p4',
#        'max_height_of_peaks_p3', 'min_height_of_peaks_p1',
#        'min_height_of_peaks_p2', 'min_height_of_peaks_p4',
#        'min_height_of_peaks_p3', 'sum_spectrum_p1', 'max_spectrum_p1',
#        'mean_spectrum_p1', 'max_freq_spectrum_p1', 'sum_spectrum_p2',
#        'max_spectrum_p2', 'mean_spectrum_p2', 'max_freq_spectrum_p2',
#        'sum_spectrum_p3', 'max_spectrum_p3', 'mean_spectrum_p3',
#        'max_freq_spectrum_p3', 'sum_spectrum_p4', 'max_spectrum_p4',
#        'mean_spectrum_p4', 'max_freq_spectrum_p4'],
#       dtype='object')

# %%
# drop the unecessary features
features  = features_raw.drop(['Unnamed: 0', 'signal_id', 'id_measurement', 'phase'], axis = 1).copy()
# Out:
#                           count          mean           std           min  \
# target                   8712.0  6.026171e-02  2.379847e-01  0.000000e+00
# number_of_peaks_p1       8712.0  3.282633e+01  7.949112e+01  0.000000e+00
# number_of_peaks_p2       8712.0  3.183942e+01  8.018707e+01  0.000000e+00
# number_of_peaks_p3       8712.0  3.176102e+01  7.946652e+01  0.000000e+00
# number_of_peaks_p4       8712.0  3.221247e+01  8.259928e+01  0.000000e+00
# mean_width_of_peaks_p1   8712.0  8.630635e-04  1.748492e-03  0.000000e+00
# mean_width_of_peaks_p2   8712.0  8.074817e-04  1.542744e-03  0.000000e+00
# mean_width_of_peaks_p4   8712.0  7.308763e-04  1.456980e-03  0.000000e+00
# mean_width_of_peaks_p3   8712.0  5.046811e-04  1.226370e-03  0.000000e+00
# max_width_of_peaks_p1    8712.0  3.334883e-03  3.637011e-03  0.000000e+00
# max_width_of_peaks_p2    8712.0  3.302283e-03  3.350480e-03  0.000000e+00
# max_width_of_peaks_p3    8712.0  3.100975e-03  3.255219e-03  0.000000e+00
# max_width_of_peaks_p4    8712.0  2.410394e-03  3.230426e-03  0.000000e+00
# min_width_of_peaks_p1    8712.0  2.728285e-04  1.509799e-03  0.000000e+00
# min_width_of_peaks_p2    8712.0  2.582206e-04  1.327438e-03  0.000000e+00
# min_width_of_peaks_p4    8712.0  2.262931e-04  1.252956e-03  0.000000e+00
# min_width_of_peaks_p3    8712.0  1.358825e-04  1.051550e-03  0.000000e+00
# mean_height_of_peaks_p1  8712.0  2.202472e+01  1.713153e+01  0.000000e+00
# mean_height_of_peaks_p2  8712.0  2.131062e+01  1.857717e+01  0.000000e+00
# mean_height_of_peaks_p4  8712.0  2.123533e+01  1.899801e+01  0.000000e+00
# mean_height_of_peaks_p3  8712.0  2.076621e+01  1.846094e+01  0.000000e+00
# max_height_of_peaks_p1   8712.0  6.781429e+01  8.039033e+01  0.000000e+00
# max_height_of_peaks_p2   8712.0  6.750096e+01  8.359665e+01  0.000000e+00
# max_height_of_peaks_p4   8712.0  6.759822e+01  8.408626e+01  0.000000e+00
# max_height_of_peaks_p3   8712.0  6.609730e+01  8.276208e+01  0.000000e+00
# min_height_of_peaks_p1   8712.0  1.039030e+01  5.024357e+00  0.000000e+00
# min_height_of_peaks_p2   8712.0  9.774325e+00  6.549486e+00  0.000000e+00
# min_height_of_peaks_p4   8712.0  9.641617e+00  6.408897e+00  0.000000e+00
# min_height_of_peaks_p3   8712.0  9.509654e+00  6.196550e+00  0.000000e+00
# sum_spectrum_p1          8712.0  3.530868e-06  5.352646e-06  1.307255e-22
# max_spectrum_p1          8712.0  1.086544e-06  1.631758e-06  1.241261e-22
# mean_spectrum_p1         8712.0  1.103396e-07  1.672702e-07  4.085171e-24
# max_freq_spectrum_p1     8712.0  8.369024e+05  1.482104e+06  0.000000e+00
# sum_spectrum_p2          8712.0  6.212455e-07  2.766406e-06  1.171639e-30
# max_spectrum_p2          8712.0  7.901966e-08  4.519965e-07  1.704961e-31
# mean_spectrum_p2         8712.0  1.941392e-08  8.645020e-08  3.661373e-32
# max_freq_spectrum_p2     8712.0  7.418862e+06  1.687201e+06  5.000000e+06
# sum_spectrum_p3          8712.0  2.237456e-06  9.254183e-06  3.019963e-32
# max_spectrum_p3          8712.0  2.665335e-07  9.447264e-07  2.735203e-33
# mean_spectrum_p3         8712.0  6.992051e-08  2.891932e-07  9.437383e-34
# max_freq_spectrum_p3     8712.0  1.303717e+07  1.583762e+06  1.000000e+07
# sum_spectrum_p4          8712.0  3.275073e-06  9.823578e-06  1.564058e-33
# max_spectrum_p4          8712.0  3.380832e-07  1.085624e-06  1.621807e-34
# mean_spectrum_p4         8712.0  1.023460e-07  3.069868e-07  4.887683e-35
# max_freq_spectrum_p4     8712.0  1.701364e+07  1.680647e+06  1.500000e+07
#
#                                   25%           50%           75%  \
# target                   0.000000e+00  0.000000e+00  0.000000e+00
# number_of_peaks_p1       3.000000e+00  1.000000e+01  3.000000e+01
# number_of_peaks_p2       2.000000e+00  9.000000e+00  2.700000e+01
# number_of_peaks_p3       2.000000e+00  9.000000e+00  2.800000e+01
# number_of_peaks_p4       2.000000e+00  9.000000e+00  2.800000e+01
# mean_width_of_peaks_p1   7.329588e-05  2.927462e-04  8.171508e-04
# mean_width_of_peaks_p2   4.746766e-05  3.000340e-04  8.291256e-04
# mean_width_of_peaks_p4   4.004865e-05  2.600330e-04  7.639245e-04
# mean_width_of_peaks_p3   2.521847e-05  1.673808e-04  4.927585e-04
# max_width_of_peaks_p1    6.413317e-04  2.265090e-03  4.740015e-03
# max_width_of_peaks_p2    2.658889e-04  2.482477e-03  5.477506e-03
# max_width_of_peaks_p3    2.220042e-04  2.174817e-03  5.019026e-03
# max_width_of_peaks_p4    8.497598e-05  1.173368e-03  3.264513e-03
# min_width_of_peaks_p1    4.097289e-08  6.645745e-08  2.422277e-05
# min_width_of_peaks_p2    3.885520e-08  4.552797e-08  1.061528e-05
# min_width_of_peaks_p4    3.830487e-08  4.486472e-08  6.839709e-06
# min_width_of_peaks_p3    3.830376e-08  4.363012e-08  8.761062e-07
# mean_height_of_peaks_p1  1.247731e+01  1.664245e+01  2.664678e+01
# mean_height_of_peaks_p2  1.120602e+01  1.648475e+01  2.836656e+01
# mean_height_of_peaks_p4  1.114737e+01  1.637225e+01  2.833730e+01
# mean_height_of_peaks_p3  1.106729e+01  1.607933e+01  2.746802e+01
# max_height_of_peaks_p1   1.577333e+01  3.055797e+01  8.173614e+01
# max_height_of_peaks_p2   1.273369e+01  2.983007e+01  8.508742e+01
# max_height_of_peaks_p4   1.254084e+01  2.887481e+01  8.683218e+01
# max_height_of_peaks_p3   1.227234e+01  2.786274e+01  8.463833e+01
# min_height_of_peaks_p1   1.004593e+01  1.026697e+01  1.097832e+01
# min_height_of_peaks_p2   1.001784e+01  1.017724e+01  1.082135e+01
# min_height_of_peaks_p4   1.001557e+01  1.017939e+01  1.080096e+01
# min_height_of_peaks_p3   1.001436e+01  1.015763e+01  1.078116e+01
# sum_spectrum_p1          3.189693e-07  1.629760e-06  4.491362e-06
# max_spectrum_p1          4.851728e-08  5.659098e-07  1.460518e-06
# mean_spectrum_p1         9.967790e-09  5.092999e-08  1.403551e-07
# max_freq_spectrum_p1     0.000000e+00  0.000000e+00  4.687500e+05
# sum_spectrum_p2          1.764359e-08  7.864020e-08  2.491131e-07
# max_spectrum_p2          1.339236e-09  6.805220e-09  2.415703e-08
# mean_spectrum_p2         5.513623e-10  2.457506e-09  7.784784e-09
# max_freq_spectrum_p2     5.937500e+06  6.718750e+06  9.218750e+06
# sum_spectrum_p3          8.739905e-09  7.283541e-08  3.913508e-07
# max_spectrum_p3          8.018398e-10  4.810539e-09  3.049029e-08
# mean_spectrum_p3         2.731220e-10  2.276107e-09  1.222971e-08
# max_freq_spectrum_p3     1.250000e+07  1.312500e+07  1.453125e+07
# sum_spectrum_p4          2.605089e-09  8.406483e-08  5.844194e-07
# max_spectrum_p4          2.040832e-10  4.612339e-09  3.418533e-08
# mean_spectrum_p4         8.140903e-11  2.627026e-09  1.826311e-08
# max_freq_spectrum_p4     1.546875e+07  1.656250e+07  1.890625e+07
#
#                                   max
# target                   1.000000e+00
# number_of_peaks_p1       1.144000e+03
# number_of_peaks_p2       1.164000e+03
# number_of_peaks_p3       1.155000e+03
# number_of_peaks_p4       1.146000e+03
# mean_width_of_peaks_p1   1.944673e-02
# mean_width_of_peaks_p2   1.932704e-02
# mean_width_of_peaks_p4   1.888989e-02
# mean_width_of_peaks_p3   1.949964e-02
# max_width_of_peaks_p1    1.949042e-02
# max_width_of_peaks_p2    1.932704e-02
# max_width_of_peaks_p3    1.950036e-02
# max_width_of_peaks_p4    1.957346e-02
# min_width_of_peaks_p1    1.944673e-02
# min_width_of_peaks_p2    1.932704e-02
# min_width_of_peaks_p4    1.888989e-02
# min_width_of_peaks_p3    1.949964e-02
# mean_height_of_peaks_p1  2.334413e+02
# mean_height_of_peaks_p2  1.565742e+02
# mean_height_of_peaks_p4  1.707950e+02
# mean_height_of_peaks_p3  1.508542e+02
# max_height_of_peaks_p1   3.040330e+02
# max_height_of_peaks_p2   3.237405e+02
# max_height_of_peaks_p4   3.302165e+02
# max_height_of_peaks_p3   3.187625e+02
# min_height_of_peaks_p1   2.334413e+02
# min_height_of_peaks_p2   1.565742e+02
# min_height_of_peaks_p4   1.404282e+02
# min_height_of_peaks_p3   1.508542e+02
# sum_spectrum_p1          7.188488e-05
# max_spectrum_p1          3.261652e-05
# mean_spectrum_p1         2.246402e-06
# max_freq_spectrum_p1     4.843750e+06
# sum_spectrum_p2          7.054104e-05
# max_spectrum_p2          1.249015e-05
# mean_spectrum_p2         2.204408e-06
# max_freq_spectrum_p2     9.843750e+06
# sum_spectrum_p3          2.005586e-04
# max_spectrum_p3          1.830010e-05
# mean_spectrum_p3         6.267457e-06
# max_freq_spectrum_p3     1.484375e+07
# sum_spectrum_p4          8.284085e-05
# max_spectrum_p4          8.191567e-06
# mean_spectrum_p4         2.588777e-06
# max_freq_spectrum_p4     1.984375e+07

# %%
scaler = MinMaxScaler()
features_norm = pd.DataFrame(scaler.fit_transform(features), columns = features.columns)
# Out:
# C:\Users\Victor\AppData\Local\conda\conda\envs\dev-capstone\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
features_norm.describe().T
# Out:
#                           count      mean       std  min       25%       50%  \
# target                   8712.0  0.060262  0.237985  0.0  0.000000  0.000000
# number_of_peaks_p1       8712.0  0.028694  0.069485  0.0  0.002622  0.008741
# number_of_peaks_p2       8712.0  0.027353  0.068889  0.0  0.001718  0.007732
# number_of_peaks_p3       8712.0  0.027499  0.068802  0.0  0.001732  0.007792
# number_of_peaks_p4       8712.0  0.028109  0.072076  0.0  0.001745  0.007853
# mean_width_of_peaks_p1   8712.0  0.044381  0.089912  0.0  0.003769  0.015054
# mean_width_of_peaks_p2   8712.0  0.041780  0.079823  0.0  0.002456  0.015524
# mean_width_of_peaks_p4   8712.0  0.038691  0.077130  0.0  0.002120  0.013766
# mean_width_of_peaks_p3   8712.0  0.025882  0.062892  0.0  0.001293  0.008584
# max_width_of_peaks_p1    8712.0  0.171104  0.186605  0.0  0.032905  0.116216
# max_width_of_peaks_p2    8712.0  0.170863  0.173357  0.0  0.013757  0.128446
# max_width_of_peaks_p3    8712.0  0.159021  0.166931  0.0  0.011385  0.111527
# max_width_of_peaks_p4    8712.0  0.123146  0.165041  0.0  0.004341  0.059947
# min_width_of_peaks_p1    8712.0  0.014030  0.077638  0.0  0.000002  0.000003
# min_width_of_peaks_p2    8712.0  0.013361  0.068683  0.0  0.000002  0.000002
# min_width_of_peaks_p4    8712.0  0.011980  0.066329  0.0  0.000002  0.000002
# min_width_of_peaks_p3    8712.0  0.006968  0.053927  0.0  0.000002  0.000002
# mean_height_of_peaks_p1  8712.0  0.094348  0.073387  0.0  0.053449  0.071292
# mean_height_of_peaks_p2  8712.0  0.136106  0.118648  0.0  0.071570  0.105284
# mean_height_of_peaks_p4  8712.0  0.124332  0.111233  0.0  0.065268  0.095859
# mean_height_of_peaks_p3  8712.0  0.137657  0.122376  0.0  0.073364  0.106589
# max_height_of_peaks_p1   8712.0  0.223049  0.264413  0.0  0.051880  0.100509
# max_height_of_peaks_p2   8712.0  0.208503  0.258221  0.0  0.039333  0.092142
# max_height_of_peaks_p4   8712.0  0.204709  0.254640  0.0  0.037978  0.087442
# max_height_of_peaks_p3   8712.0  0.207356  0.259636  0.0  0.038500  0.087409
# min_height_of_peaks_p1   8712.0  0.044509  0.021523  0.0  0.043034  0.043981
# min_height_of_peaks_p2   8712.0  0.062426  0.041830  0.0  0.063981  0.064999
# min_height_of_peaks_p4   8712.0  0.068659  0.045638  0.0  0.071322  0.072488
# min_height_of_peaks_p3   8712.0  0.063039  0.041076  0.0  0.066384  0.067334
# sum_spectrum_p1          8712.0  0.049118  0.074461  0.0  0.004437  0.022672
# max_spectrum_p1          8712.0  0.033313  0.050029  0.0  0.001488  0.017350
# mean_spectrum_p1         8712.0  0.049118  0.074461  0.0  0.004437  0.022672
# max_freq_spectrum_p1     8712.0  0.172780  0.305983  0.0  0.000000  0.000000
# sum_spectrum_p2          8712.0  0.008807  0.039217  0.0  0.000250  0.001115
# max_spectrum_p2          8712.0  0.006327  0.036188  0.0  0.000107  0.000545
# mean_spectrum_p2         8712.0  0.008807  0.039217  0.0  0.000250  0.001115
# max_freq_spectrum_p2     8712.0  0.499378  0.348325  0.0  0.193548  0.354839
# sum_spectrum_p3          8712.0  0.011156  0.046142  0.0  0.000044  0.000363
# max_spectrum_p3          8712.0  0.014565  0.051624  0.0  0.000044  0.000263
# mean_spectrum_p3         8712.0  0.011156  0.046142  0.0  0.000044  0.000363
# max_freq_spectrum_p3     8712.0  0.627029  0.326970  0.0  0.516129  0.645161
# sum_spectrum_p4          8712.0  0.039535  0.118584  0.0  0.000031  0.001015
# max_spectrum_p4          8712.0  0.041272  0.132529  0.0  0.000025  0.000563
# mean_spectrum_p4         8712.0  0.039535  0.118584  0.0  0.000031  0.001015
# max_freq_spectrum_p4     8712.0  0.415719  0.346972  0.0  0.096774  0.322581
#
#                               75%  max
# target                   0.000000  1.0
# number_of_peaks_p1       0.026224  1.0
# number_of_peaks_p2       0.023196  1.0
# number_of_peaks_p3       0.024242  1.0
# number_of_peaks_p4       0.024433  1.0
# mean_width_of_peaks_p1   0.042020  1.0
# mean_width_of_peaks_p2   0.042900  1.0
# mean_width_of_peaks_p4   0.040441  1.0
# mean_width_of_peaks_p3   0.025270  1.0
# max_width_of_peaks_p1    0.243197  1.0
# max_width_of_peaks_p2    0.283412  1.0
# max_width_of_peaks_p3    0.257381  1.0
# max_width_of_peaks_p4    0.166783  1.0
# min_width_of_peaks_p1    0.001246  1.0
# min_width_of_peaks_p2    0.000549  1.0
# min_width_of_peaks_p4    0.000362  1.0
# min_width_of_peaks_p3    0.000045  1.0
# mean_height_of_peaks_p1  0.114148  1.0
# mean_height_of_peaks_p2  0.181170  1.0
# mean_height_of_peaks_p4  0.165914  1.0
# mean_height_of_peaks_p3  0.182083  1.0
# max_height_of_peaks_p1   0.268840  1.0
# max_height_of_peaks_p2   0.262826  1.0
# max_height_of_peaks_p4   0.262955  1.0
# max_height_of_peaks_p3   0.265522  1.0
# min_height_of_peaks_p1   0.047028  1.0
# min_height_of_peaks_p2   0.069113  1.0
# min_height_of_peaks_p4   0.076914  1.0
# min_height_of_peaks_p3   0.071467  1.0
# sum_spectrum_p1          0.062480  1.0
# max_spectrum_p1          0.044778  1.0
# mean_spectrum_p1         0.062480  1.0
# max_freq_spectrum_p1     0.096774  1.0
# sum_spectrum_p2          0.003531  1.0
# max_spectrum_p2          0.001934  1.0
# mean_spectrum_p2         0.003531  1.0
# max_freq_spectrum_p2     0.870968  1.0
# sum_spectrum_p3          0.001951  1.0
# max_spectrum_p3          0.001666  1.0
# mean_spectrum_p3         0.001951  1.0
# max_freq_spectrum_p3     0.935484  1.0
# sum_spectrum_p4          0.007055  1.0
# max_spectrum_p4          0.004173  1.0
# mean_spectrum_p4         0.007055  1.0
# max_freq_spectrum_p4     0.806452  1.0

# %%
fig = plt.figure(figsize = (12,12))
sns.heatmap(features_norm.corr())
plt.savefig(report_dir + '/ds_heatmap.png')

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly 

plotly.tools.set_credentials_file(username='victorspruela', api_key='QsriLXOL5rTdL3vnzeda')
